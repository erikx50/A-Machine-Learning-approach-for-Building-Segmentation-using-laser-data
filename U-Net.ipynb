# %% [markdown]
# # U-Net

# %% [markdown]
# ## Imports

# %%
from tensorflow.keras import layers, optimizers, backend, Model
from tensorflow.keras.applications import EfficientNetB4, EfficientNetV2S, ResNet50V2, DenseNet201

# %% [markdown]
# ## Full model

# %% [markdown]
# <img src='images/unet.png' width='600'/>

# %%
# U-Net
def unet(input_shape=(512, 512, 3)):
    """
    Creates a neural network using the U-Net architecture.
    Args:
        input_shape: The size of the input image.
    Returns:
        A U-Net model.
    """
    # Encoder Part
    # Layer 1
    inputs = layers.Input(input_shape)
    inputs_rescaled = layers.Lambda(lambda x: x / 255)(inputs)  # Rescale input pixel values to floating point values
    c1 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs_rescaled)
    c1 = layers.BatchNormalization()(c1)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    c1 = layers.BatchNormalization()(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    # Layer 2
    c2 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = layers.BatchNormalization()(c2)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    c2 = layers.BatchNormalization()(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    # Layer 3
    c3 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = layers.BatchNormalization()(c3)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    c3 = layers.BatchNormalization()(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    # Layer 4
    c4 = layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = layers.BatchNormalization()(c4)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    c4 = layers.BatchNormalization()(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Layer 5
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = layers.BatchNormalization()(c5)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    c5 = layers.BatchNormalization()(c5)

    # Decoder Part
    # Layer 6
    u6 = layers.Conv2DTranspose(512, (3, 3), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = layers.BatchNormalization()(c6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
    c6 = layers.BatchNormalization()(c6)

    # Layer 7
    u7 = layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = layers.BatchNormalization()(c7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
    c7 = layers.BatchNormalization()(c7)

    # Layer 8
    u8 = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = layers.BatchNormalization()(c8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
    c8 = layers.BatchNormalization()(c8)

    # Layer 9
    u9 = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1], axis=3)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = layers.BatchNormalization()(c9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
    c9 = layers.BatchNormalization()(c9)

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    # Compiling model
    model = Model(inputs=[inputs], outputs=[outputs], name='UNet')
    return model

# %%
model = unet()

# %%
model.summary()
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  lambda_3 (Lambda)              (None, 512, 512, 3)  0           ['input_5[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 512, 512, 64  1792        ['lambda_3[0][0]']
#                                 )
#
#  batch_normalization_46 (BatchN  (None, 512, 512, 64  256        ['conv2d_48[0][0]']
#  ormalization)                  )
#
#  conv2d_49 (Conv2D)             (None, 512, 512, 64  36928       ['batch_normalization_46[0][0]']
#                                 )
#
#  batch_normalization_47 (BatchN  (None, 512, 512, 64  256        ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 256, 256, 64  0          ['batch_normalization_47[0][0]']
#  )                              )
#
#  conv2d_50 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_12[0][0]']
#                                 8)
#
#  batch_normalization_48 (BatchN  (None, 256, 256, 12  512        ['conv2d_50[0][0]']
#  ormalization)                  8)
#
#  conv2d_51 (Conv2D)             (None, 256, 256, 12  147584      ['batch_normalization_48[0][0]']
#                                 8)
#
#  batch_normalization_49 (BatchN  (None, 256, 256, 12  512        ['conv2d_51[0][0]']
#  ormalization)                  8)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 128, 128, 12  0          ['batch_normalization_49[0][0]']
#  )                              8)
#
#  conv2d_52 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_13[0][0]']
#                                 6)
#
#  batch_normalization_50 (BatchN  (None, 128, 128, 25  1024       ['conv2d_52[0][0]']
#  ormalization)                  6)
#
#  conv2d_53 (Conv2D)             (None, 128, 128, 25  590080      ['batch_normalization_50[0][0]']
#                                 6)
#
#  batch_normalization_51 (BatchN  (None, 128, 128, 25  1024       ['conv2d_53[0][0]']
#  ormalization)                  6)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 64, 64, 256)  0          ['batch_normalization_51[0][0]']
#  )
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_54[0][0]']
#  ormalization)
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 512)  2359808     ['batch_normalization_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_55[0][0]']
#  ormalization)
#
#  max_pooling2d_15 (MaxPooling2D  (None, 32, 32, 512)  0          ['batch_normalization_53[0][0]']
#  )
#
#  conv2d_56 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_15[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  conv2d_57 (Conv2D)             (None, 32, 32, 1024  9438208     ['batch_normalization_54[0][0]']
#                                 )
#
#  batch_normalization_55 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_57[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_9 (Conv2DTran  (None, 64, 64, 512)  4719104    ['batch_normalization_55[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 1024  0           ['conv2d_transpose_9[0][0]',
#                                 )                                 'batch_normalization_53[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_9[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_58[0][0]']
#  ormalization)
#
#  conv2d_59 (Conv2D)             (None, 64, 64, 512)  2359808     ['batch_normalization_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_59[0][0]']
#  ormalization)
#
#  conv2d_transpose_10 (Conv2DTra  (None, 128, 128, 25  1179904    ['batch_normalization_57[0][0]']
#  nspose)                        6)
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 51  0           ['conv2d_transpose_10[0][0]',
#                                 2)                                'batch_normalization_51[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_10[0][0]']
#                                 6)
#
#  batch_normalization_58 (BatchN  (None, 128, 128, 25  1024       ['conv2d_60[0][0]']
#  ormalization)                  6)
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 25  590080      ['batch_normalization_58[0][0]']
#                                 6)
#
#  batch_normalization_59 (BatchN  (None, 128, 128, 25  1024       ['conv2d_61[0][0]']
#  ormalization)                  6)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 256, 256, 12  295040     ['batch_normalization_59[0][0]']
#  nspose)                        8)
#
#  concatenate_11 (Concatenate)   (None, 256, 256, 25  0           ['conv2d_transpose_11[0][0]',
#                                 6)                                'batch_normalization_49[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_11[0][0]']
#                                 8)
#
#  batch_normalization_60 (BatchN  (None, 256, 256, 12  512        ['conv2d_62[0][0]']
#  ormalization)                  8)
#
#  conv2d_63 (Conv2D)             (None, 256, 256, 12  147584      ['batch_normalization_60[0][0]']
#                                 8)
#
#  batch_normalization_61 (BatchN  (None, 256, 256, 12  512        ['conv2d_63[0][0]']
#  ormalization)                  8)
#
#  conv2d_transpose_12 (Conv2DTra  (None, 512, 512, 64  73792      ['batch_normalization_61[0][0]']
#  nspose)                        )
#
#  concatenate_12 (Concatenate)   (None, 512, 512, 12  0           ['conv2d_transpose_12[0][0]',
#                                 8)                                'batch_normalization_47[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_12[0][0]']
#                                 )
#
#  batch_normalization_62 (BatchN  (None, 512, 512, 64  256        ['conv2d_64[0][0]']
#  ormalization)                  )
#
#  conv2d_65 (Conv2D)             (None, 512, 512, 64  36928       ['batch_normalization_62[0][0]']
#                                 )
#
#  batch_normalization_63 (BatchN  (None, 512, 512, 64  256        ['conv2d_65[0][0]']
#  ormalization)                  )
#
#  conv2d_66 (Conv2D)             (None, 512, 512, 1)  65          ['batch_normalization_63[0][0]']
#
# ==================================================================================================
# Total params: 34,536,897
# Trainable params: 34,525,121
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ## Block functions

# %%
def conv_block(input, num_filters):
    """
    Creates a block consisting of two convolutional layers.
    Args:
        input: The output of the previous up-convolution.
        num_filters: Number of filters to be used in the convolution.
    Returns:
        The result of the final calculation of the current layer.
    """
    x = layers.Conv2D(num_filters, 3, activation='relu', kernel_initializer='he_normal',  padding='same')(input)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(num_filters, 3, activation='relu', kernel_initializer='he_normal', padding='same')(x)
    x = layers.BatchNormalization()(x)
    return x


def decoder_block(input, skip_features, num_filters):
    """
    Create a decoder block used in the decoder part of the network.
    Args:
        input: The output of the previous layer.
        skip_features: The features of the same size from the encoder part of the network.
        num_filters: Number of filters to be used in the convolution.
    Returns:
        The result of the final calculation of the current layer.
    """
    x = layers.Conv2DTranspose(num_filters, (3, 3), strides=2, activation='relu', kernel_initializer='he_normal', padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.concatenate([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %% [markdown]
# ## EfficientNetB4

# %%
# EfficientNetB4 UNet
def EfficientNetB4_unet(input_shape=(512, 512, 3), weight='imagenet'):
    """
    Creates a neural network using the U-Net architecture and EfficientNetB4 as backbone.
    Args:
        input_shape: The size of the input image.
        weight: Pre-trained weights.
    Returns:
        A U-Net model using EfficientNetB4 as backbone.
    """
    # Input
    inputs = layers.Input(input_shape)

    # Loading pre trained model
    EffNetB4 = EfficientNetB4(include_top=False, weights=weight, input_tensor=inputs)

    # Encoder
    s1 = EffNetB4.get_layer('rescaling').output  # 512 x 512
    s2 = EffNetB4.get_layer('block2a_expand_activation').output  # 256 x 256
    s3 = EffNetB4.get_layer('block3a_expand_activation').output  # 128 x 128
    s4 = EffNetB4.get_layer('block4a_expand_activation').output  # 64 x 64

    # Bottleneck
    b1 = EffNetB4.get_layer('block6a_expand_activation').output  # 32 x 32

    # Decoder
    d1 = decoder_block(b1, s4, 512)  # 64 x 64
    d2 = decoder_block(d1, s3, 256)    # 128 x 128
    d3 = decoder_block(d2, s2, 128)   # 256 x 256
    d4 = decoder_block(d3, s1, 64)   # 512 x 512

    # Output
    outputs = layers.Conv2D(1, 1, padding='same', activation='sigmoid')(d4)

    model = Model(inputs, outputs, name='EfficientNetB4_U-Net')
    return model

# %%
model = EfficientNetB4_unet()

# %%
model.summary()
# Out:
# Model: "EfficientNetB4_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 512, 512, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 512, 512, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 512, 512, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 513, 513, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 256, 256, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 256, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 256, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 256, 256, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 256, 256, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 256, 256, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 256, 256, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 256, 256, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 256, 256, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 256, 256, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 256, 256, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 256, 256, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 256, 256, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 256, 256, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 256, 256, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#  block2a_expand_conv (Conv2D)   (None, 256, 256, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 256, 256, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 256, 256, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 257, 257, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 128, 128, 14  1296       ['block2a_dwconv_pad[0][0]']
#  D)                             4)
#
#  block2a_bn (BatchNormalization  (None, 128, 128, 14  576        ['block2a_dwconv[0][0]']
#  )                              4)
#
#  block2a_activation (Activation  (None, 128, 128, 14  0          ['block2a_bn[0][0]']
#  )                              4)
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 128, 128, 14  0           ['block2a_activation[0][0]',
#                                 4)                                'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 128, 128, 32  4608        ['block2a_se_excite[0][0]']
#                                 )
#
#  block2a_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2a_project_bn[0][0]']
#                                 2)
#
#  block2b_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2b_expand_conv[0][0]']
#  ization)                       2)
#
#  block2b_expand_activation (Act  (None, 128, 128, 19  0          ['block2b_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2b_dwconv (DepthwiseConv2  (None, 128, 128, 19  1728       ['block2b_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2b_bn (BatchNormalization  (None, 128, 128, 19  768        ['block2b_dwconv[0][0]']
#  )                              2)
#
#  block2b_activation (Activation  (None, 128, 128, 19  0          ['block2b_bn[0][0]']
#  )                              2)
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 128, 128, 19  0           ['block2b_activation[0][0]',
#                                 2)                                'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 128, 128, 32  6144        ['block2b_se_excite[0][0]']
#                                 )
#
#  block2b_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 128, 128, 32  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 128, 128, 32  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2b_add[0][0]']
#                                 2)
#
#  block2c_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2c_expand_conv[0][0]']
#  ization)                       2)
#
#  block2c_expand_activation (Act  (None, 128, 128, 19  0          ['block2c_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2c_dwconv (DepthwiseConv2  (None, 128, 128, 19  1728       ['block2c_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2c_bn (BatchNormalization  (None, 128, 128, 19  768        ['block2c_dwconv[0][0]']
#  )                              2)
#
#  block2c_activation (Activation  (None, 128, 128, 19  0          ['block2c_bn[0][0]']
#  )                              2)
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 128, 128, 19  0           ['block2c_activation[0][0]',
#                                 2)                                'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 128, 128, 32  6144        ['block2c_se_excite[0][0]']
#                                 )
#
#  block2c_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 128, 128, 32  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 128, 128, 32  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2c_add[0][0]']
#                                 2)
#
#  block2d_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2d_expand_conv[0][0]']
#  ization)                       2)
#
#  block2d_expand_activation (Act  (None, 128, 128, 19  0          ['block2d_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2d_dwconv (DepthwiseConv2  (None, 128, 128, 19  1728       ['block2d_expand_activation[0][0]
#  D)                             2)                               ']
#
#  block2d_bn (BatchNormalization  (None, 128, 128, 19  768        ['block2d_dwconv[0][0]']
#  )                              2)
#
#  block2d_activation (Activation  (None, 128, 128, 19  0          ['block2d_bn[0][0]']
#  )                              2)
#
#  block2d_se_squeeze (GlobalAver  (None, 192)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 128, 128, 19  0           ['block2d_activation[0][0]',
#                                 2)                                'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 128, 128, 32  6144        ['block2d_se_excite[0][0]']
#                                 )
#
#  block2d_project_bn (BatchNorma  (None, 128, 128, 32  128        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 128, 128, 32  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 128, 128, 32  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 128, 128, 19  6144        ['block2d_add[0][0]']
#                                 2)
#
#  block3a_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block3a_expand_conv[0][0]']
#  ization)                       2)
#
#  block3a_expand_activation (Act  (None, 128, 128, 19  0          ['block3a_expand_bn[0][0]']
#  ivation)                       2)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 131, 131, 19  0          ['block3a_expand_activation[0][0]
#  g2D)                           2)                               ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 64, 64, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 64, 64, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 64, 64, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 64, 64, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 64, 64, 56)   10752       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 64, 64, 336)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 64, 64, 336)  8400       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 64, 64, 336)  1344       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 64, 64, 336)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 336)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 64, 64, 336)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 64, 64, 56)   18816       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 64, 64, 56)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 64, 64, 56)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 64, 64, 336)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 64, 64, 336)  8400       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 64, 64, 336)  1344       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 64, 64, 336)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 336)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 64, 64, 336)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 64, 64, 56)   18816       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 64, 64, 56)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 64, 64, 56)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 64, 64, 336)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 64, 64, 336)  8400       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 64, 64, 336)  1344       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 64, 64, 336)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 336)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 64, 64, 336)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 64, 64, 56)   18816       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 64, 64, 56)  224         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 64, 64, 56)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 64, 64, 56)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 64, 64, 336)  18816       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 64, 64, 336)  1344       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 64, 64, 336)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 65, 65, 336)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 32, 32, 336)  3024       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 32, 32, 336)  1344       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 32, 32, 336)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 336)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 32, 32, 336)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 32, 32, 112)  37632       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 32, 32, 112)  448        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 32, 32, 672)  75264       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 32, 32, 672)  2688       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 32, 32, 672)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 32, 32, 672)  6048       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 32, 32, 672)  2688       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 32, 32, 672)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 672)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 32, 32, 672)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 32, 32, 112)  75264       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 32, 32, 112)  448        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 32, 32, 112)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 32, 32, 112)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 32, 32, 672)  75264       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 32, 32, 672)  2688       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 32, 32, 672)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
# ...
#  )
#
#  block5e_activation (Activation  (None, 32, 32, 960)  0          ['block5e_bn[0][0]']
#  )
#
#  block5e_se_squeeze (GlobalAver  (None, 960)         0           ['block5e_activation[0][0]']
#  agePooling2D)
#
#  block5e_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5e_se_squeeze[0][0]']
#
#  block5e_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5e_se_reshape[0][0]']
#
#  block5e_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5e_se_reduce[0][0]']
#
#  block5e_se_excite (Multiply)   (None, 32, 32, 960)  0           ['block5e_activation[0][0]',
#                                                                   'block5e_se_expand[0][0]']
#
#  block5e_project_conv (Conv2D)  (None, 32, 32, 160)  153600      ['block5e_se_excite[0][0]']
#
#  block5e_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block5e_project_conv[0][0]']
#  lization)
#
#  block5e_drop (Dropout)         (None, 32, 32, 160)  0           ['block5e_project_bn[0][0]']
#
#  block5e_add (Add)              (None, 32, 32, 160)  0           ['block5e_drop[0][0]',
#                                                                   'block5d_add[0][0]']
#
#  block5f_expand_conv (Conv2D)   (None, 32, 32, 960)  153600      ['block5e_add[0][0]']
#
#  block5f_expand_bn (BatchNormal  (None, 32, 32, 960)  3840       ['block5f_expand_conv[0][0]']
#  ization)
#  block5f_expand_activation (Act  (None, 32, 32, 960)  0          ['block5f_expand_bn[0][0]']
#  ivation)
#
#  block5f_dwconv (DepthwiseConv2  (None, 32, 32, 960)  24000      ['block5f_expand_activation[0][0]
#  D)                                                              ']
#
#  block5f_bn (BatchNormalization  (None, 32, 32, 960)  3840       ['block5f_dwconv[0][0]']
#  )
#
#  block5f_activation (Activation  (None, 32, 32, 960)  0          ['block5f_bn[0][0]']
#  )
#
#  block5f_se_squeeze (GlobalAver  (None, 960)         0           ['block5f_activation[0][0]']
#  agePooling2D)
#
#  block5f_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5f_se_squeeze[0][0]']
#
#  block5f_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5f_se_reshape[0][0]']
#
#  block5f_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5f_se_reduce[0][0]']
#
#  block5f_se_excite (Multiply)   (None, 32, 32, 960)  0           ['block5f_activation[0][0]',
#                                                                   'block5f_se_expand[0][0]']
#
#  block5f_project_conv (Conv2D)  (None, 32, 32, 160)  153600      ['block5f_se_excite[0][0]']
#
#  block5f_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block5f_project_conv[0][0]']
#  lization)
#
#  block5f_drop (Dropout)         (None, 32, 32, 160)  0           ['block5f_project_bn[0][0]']
#
#  block5f_add (Add)              (None, 32, 32, 160)  0           ['block5f_drop[0][0]',
#                                                                   'block5e_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 32, 32, 960)  153600      ['block5f_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 32, 32, 960)  3840       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 32, 32, 960)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  4424192    ['block6a_expand_activation[0][0]
#  ose)                                                            ']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 512)  2048       ['conv2d_transpose[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 64, 64, 848)  0           ['batch_normalization[0][0]',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d (Conv2D)                (None, 64, 64, 512)  3908096     ['concatenate[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d[0][0]']
#  rmalization)
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 512)  2359808     ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  1179904    ['batch_normalization_2[0][0]']
#  spose)                         6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)                   6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 44  0           ['batch_normalization_3[0][0]',
#                                 8)                                'block3a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 25  1032448     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_2[0][0]']
#  rmalization)                   6)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 25  590080      ['batch_normalization_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  295040     ['batch_normalization_5[0][0]']
#  spose)                         8)
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 12  512        ['conv2d_transpose_2[0][0]']
#  rmalization)                   8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 27  0           ['batch_normalization_6[0][0]',
#                                 2)                                'block2a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  313472      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  147584      ['batch_normalization_7[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  73792      ['batch_normalization_8[0][0]']
#  spose)                         )
#
#  batch_normalization_9 (BatchNo  (None, 512, 512, 64  256        ['conv2d_transpose_3[0][0]']
#  rmalization)                   )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 67  0           ['batch_normalization_9[0][0]',
#                                 )                                 'rescaling[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 512, 512, 64  256        ['conv2d_6[0][0]']
#  ormalization)                  )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 64  36928       ['batch_normalization_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 512, 512, 64  256        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 1)  65          ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 18,253,672
# Trainable params: 18,197,329
# Non-trainable params: 56,343
# __________________________________________________________________________________________________

# %% [markdown]
# ## EfficientNetV2S

# %%
def EfficientNetV2S_unet(input_shape=(512, 512, 3), weight='imagenet'):
    """
    Creates a neural network using the U-Net architecture and EfficientNetV2S as backbone.
    Args:
        input_shape: The size of the input image.
        weight: Pre-trained weights.
    Returns:
        A U-Net model using EfficientNetB4 as backbone.
    """
    # Input
    inputs = layers.Input(input_shape)

    # Loading pre trained model
    EffNetV2S = EfficientNetV2S(include_top=False, weights=weight, input_tensor=inputs)

    # Encoder
    s1 = EffNetV2S.get_layer('rescaling').output  # 512 x 512
    s2 = EffNetV2S.get_layer('block1b_add').output  # 256 x 256
    s3 = EffNetV2S.get_layer('block2d_add').output  # 128 x 128
    s4 = EffNetV2S.get_layer('block4a_expand_activation').output  # 64 x 64

    # Bottleneck
    b1 = EffNetV2S.get_layer('block6a_expand_activation').output  # 32 x 32

    # Decoder
    d1 = decoder_block(b1, s4, 512)  # 64 x 64
    d2 = decoder_block(d1, s3, 256)    # 128 x 128
    d3 = decoder_block(d2, s2, 128)   # 256 x 256
    d4 = decoder_block(d3, s1, 64)   # 512 x 512

    # Output
    outputs = layers.Conv2D(1, 1, padding='same', activation='sigmoid')(d4)

    model = Model(inputs, outputs, name='EfficientNetV2S_U-Net')
    return model

# %%
model = EfficientNetV2S_unet()

# %%
model.summary()
# Out:
# Model: "EfficientNetV2S_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 512, 512, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 256, 256, 24  648         ['rescaling[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 256, 256, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 256, 256, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 256, 256, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 256, 256, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 256, 256, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 256, 256, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 256, 256, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 256, 256, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 256, 256, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 256, 256, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 128, 128, 96  20736       ['block1b_add[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 128, 128, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 128, 128, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_project_conv (Conv2D)  (None, 128, 128, 48  4608        ['block2a_expand_activation[0][0]
#                                 )                                ']
#
#  block2a_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2a_project_conv[0][0]']
#  lization)                      )
#
#  block2b_expand_conv (Conv2D)   (None, 128, 128, 19  82944       ['block2a_project_bn[0][0]']
#                                 2)
#
#  block2b_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2b_expand_conv[0][0]']
#  ization)                       2)
#
#  block2b_expand_activation (Act  (None, 128, 128, 19  0          ['block2b_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2b_project_conv (Conv2D)  (None, 128, 128, 48  9216        ['block2b_expand_activation[0][0]
#                                 )                                ']
#
#  block2b_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2b_project_conv[0][0]']
#  lization)                      )
#
#  block2b_drop (Dropout)         (None, 128, 128, 48  0           ['block2b_project_bn[0][0]']
#                                 )
#
#  block2b_add (Add)              (None, 128, 128, 48  0           ['block2b_drop[0][0]',
#                                 )                                 'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 128, 128, 19  82944       ['block2b_add[0][0]']
#                                 2)
#
#  block2c_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2c_expand_conv[0][0]']
#  ization)                       2)
#
#  block2c_expand_activation (Act  (None, 128, 128, 19  0          ['block2c_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2c_project_conv (Conv2D)  (None, 128, 128, 48  9216        ['block2c_expand_activation[0][0]
#                                 )                                ']
#
#  block2c_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2c_project_conv[0][0]']
#  lization)                      )
#
#  block2c_drop (Dropout)         (None, 128, 128, 48  0           ['block2c_project_bn[0][0]']
#                                 )
#
#  block2c_add (Add)              (None, 128, 128, 48  0           ['block2c_drop[0][0]',
#                                 )                                 'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 128, 128, 19  82944       ['block2c_add[0][0]']
#                                 2)
#
#  block2d_expand_bn (BatchNormal  (None, 128, 128, 19  768        ['block2d_expand_conv[0][0]']
#  ization)                       2)
#
#  block2d_expand_activation (Act  (None, 128, 128, 19  0          ['block2d_expand_bn[0][0]']
#  ivation)                       2)
#
#  block2d_project_conv (Conv2D)  (None, 128, 128, 48  9216        ['block2d_expand_activation[0][0]
#                                 )                                ']
#
#  block2d_project_bn (BatchNorma  (None, 128, 128, 48  192        ['block2d_project_conv[0][0]']
#  lization)                      )
#
#  block2d_drop (Dropout)         (None, 128, 128, 48  0           ['block2d_project_bn[0][0]']
#                                 )
#
#  block2d_add (Add)              (None, 128, 128, 48  0           ['block2d_drop[0][0]',
#                                 )                                 'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 64, 64, 192)  82944       ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 64, 64, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 64, 64, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 64, 64, 64)   12288       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 64, 64, 256)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 64, 64, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 64, 64, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 64, 64, 256)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 64, 64, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 64, 64, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 64, 64, 256)  147456      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 64, 64, 256)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 64, 64, 64)   16384       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 64, 64, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 64, 64, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 64, 64, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 64, 64, 256)  16384       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 64, 64, 256)  1024       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 64, 64, 256)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 32, 32, 256)  2304       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 32, 32, 256)  1024       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 32, 32, 256)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 256)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 256)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 16)     4112        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 256)    4352        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 32, 32, 256)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 32, 32, 128)  32768       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 32, 32, 128)  512        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 32, 32, 512)  65536       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 32, 32, 512)  2048       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 32, 32, 512)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 32, 32, 512)  4608       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 32, 32, 512)  2048       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 32, 32, 512)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 512)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 32, 32, 512)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 32, 32, 128)  65536       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 32, 32, 128)  512        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 32, 32, 128)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 32, 32, 128)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 32, 32, 512)  65536       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 32, 32, 512)  2048       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 32, 32, 512)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 32, 32, 512)  4608       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 32, 32, 512)  2048       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 32, 32, 512)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 512)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 32, 32, 512)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 32, 32, 128)  65536       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 32, 32, 128)  512        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 32, 32, 128)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 32, 32, 128)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 32, 32, 512)  65536       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 32, 32, 512)  2048       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 32, 32, 512)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 32, 32, 512)  4608       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 32, 32, 512)  2048       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 32, 32, 512)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 512)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4d_se_reduce[0][0]']
#  block4d_se_excite (Multiply)   (None, 32, 32, 512)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 32, 32, 128)  65536       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 32, 32, 128)  512        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 32, 32, 128)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 32, 32, 128)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 32, 32, 512)  65536       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 32, 32, 512)  2048       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 32, 32, 512)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 32, 32, 512)  4608       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 32, 32, 512)  2048       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 32, 32, 512)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 512)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 32, 32, 512)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 32, 32, 128)  65536       ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 32, 32, 128)  512        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 32, 32, 128)  0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 32, 32, 128)  0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 32, 32, 512)  65536       ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 32, 32, 512)  2048       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 32, 32, 512)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 32, 32, 512)  4608       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 32, 32, 512)  2048       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 32, 32, 512)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 512)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 32, 32, 512)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 32, 32, 128)  65536       ['block4f_se_excite[0][0]']
#  block4f_project_bn (BatchNorma  (None, 32, 32, 128)  512        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 32, 32, 128)  0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 32, 32, 128)  0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 32, 32, 768)  98304       ['block4f_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 32, 32, 768)  3072       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 32, 32, 768)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 32, 32, 768)  6912       ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 32, 32, 768)  3072       ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 32, 32, 768)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 768)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 32)     24608       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 768)    25344       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 32, 32, 768)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 32, 32, 160)  122880      ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 32, 32, 960)  153600      ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 32, 32, 960)  3840       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 32, 32, 960)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 32, 32, 960)  8640       ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 32, 32, 960)  3840       ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 32, 32, 960)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 960)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 32, 32, 960)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 32, 32, 160)  153600      ['block5b_se_excite[0][0]']
# ...
#  2D)                                                             ']
#
#  block5h_bn (BatchNormalization  (None, 32, 32, 960)  3840       ['block5h_dwconv2[0][0]']
#  )
#
#  block5h_activation (Activation  (None, 32, 32, 960)  0          ['block5h_bn[0][0]']
#  )
#
#  block5h_se_squeeze (GlobalAver  (None, 960)         0           ['block5h_activation[0][0]']
#  agePooling2D)
#
#  block5h_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5h_se_squeeze[0][0]']
#
#  block5h_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5h_se_reshape[0][0]']
#
#  block5h_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5h_se_reduce[0][0]']
#
#  block5h_se_excite (Multiply)   (None, 32, 32, 960)  0           ['block5h_activation[0][0]',
#                                                                   'block5h_se_expand[0][0]']
#
#  block5h_project_conv (Conv2D)  (None, 32, 32, 160)  153600      ['block5h_se_excite[0][0]']
#
#  block5h_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block5h_project_conv[0][0]']
#  lization)
#
#  block5h_drop (Dropout)         (None, 32, 32, 160)  0           ['block5h_project_bn[0][0]']
#
#  block5h_add (Add)              (None, 32, 32, 160)  0           ['block5h_drop[0][0]',
#                                                                   'block5g_add[0][0]']
#
#  block5i_expand_conv (Conv2D)   (None, 32, 32, 960)  153600      ['block5h_add[0][0]']
#
#  block5i_expand_bn (BatchNormal  (None, 32, 32, 960)  3840       ['block5i_expand_conv[0][0]']
#  ization)
#
#  block5i_expand_activation (Act  (None, 32, 32, 960)  0          ['block5i_expand_bn[0][0]']
#  ivation)
#
#  block5i_dwconv2 (DepthwiseConv  (None, 32, 32, 960)  8640       ['block5i_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5i_bn (BatchNormalization  (None, 32, 32, 960)  3840       ['block5i_dwconv2[0][0]']
#  )
#
#  block5i_activation (Activation  (None, 32, 32, 960)  0          ['block5i_bn[0][0]']
#  )
#  block5i_se_squeeze (GlobalAver  (None, 960)         0           ['block5i_activation[0][0]']
#  agePooling2D)
#
#  block5i_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5i_se_squeeze[0][0]']
#
#  block5i_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5i_se_reshape[0][0]']
#
#  block5i_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5i_se_reduce[0][0]']
#
#  block5i_se_excite (Multiply)   (None, 32, 32, 960)  0           ['block5i_activation[0][0]',
#                                                                   'block5i_se_expand[0][0]']
#
#  block5i_project_conv (Conv2D)  (None, 32, 32, 160)  153600      ['block5i_se_excite[0][0]']
#
#  block5i_project_bn (BatchNorma  (None, 32, 32, 160)  640        ['block5i_project_conv[0][0]']
#  lization)
#
#  block5i_drop (Dropout)         (None, 32, 32, 160)  0           ['block5i_project_bn[0][0]']
#
#  block5i_add (Add)              (None, 32, 32, 160)  0           ['block5i_drop[0][0]',
#                                                                   'block5h_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 32, 32, 960)  153600      ['block5i_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 32, 32, 960)  3840       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 32, 32, 960)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  4424192    ['block6a_expand_activation[0][0]
#  ose)                                                            ']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 512)  2048       ['conv2d_transpose[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 64, 64, 768)  0           ['batch_normalization[0][0]',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d (Conv2D)                (None, 64, 64, 512)  3539456     ['concatenate[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d[0][0]']
#  rmalization)
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 512)  2359808     ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  1179904    ['batch_normalization_2[0][0]']
#  spose)                         6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)                   6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 30  0           ['batch_normalization_3[0][0]',
#                                 4)                                'block2d_add[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 25  700672      ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_2[0][0]']
#  rmalization)                   6)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 25  590080      ['batch_normalization_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  295040     ['batch_normalization_5[0][0]']
#  spose)                         8)
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 12  512        ['conv2d_transpose_2[0][0]']
#  rmalization)                   8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 15  0           ['batch_normalization_6[0][0]',
#                                 2)                                'block1b_add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  175232      ['concatenate_2[0][0]']
#                                 8)
#  batch_normalization_7 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  147584      ['batch_normalization_7[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  73792      ['batch_normalization_8[0][0]']
#  spose)                         )
#
#  batch_normalization_9 (BatchNo  (None, 512, 512, 64  256        ['conv2d_transpose_3[0][0]']
#  rmalization)                   )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 67  0           ['batch_normalization_9[0][0]',
#                                 )                                 'rescaling[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 512, 512, 64  256        ['conv2d_6[0][0]']
#  ormalization)                  )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 64  36928       ['batch_normalization_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 512, 512, 64  256        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 1)  65          ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 19,069,561
# Trainable params: 19,008,105
# Non-trainable params: 61,456
# __________________________________________________________________________________________________

# %% [markdown]
# ## ResNet50V2

# %%
def ResNet50V2_unet(input_shape=(512, 512, 3), weight='imagenet'):
    """
    Creates a neural network using the U-Net architecture and ResNet50V2 as backbone.
    Args:
        input_shape: The size of the input image.
        weight: Pre-trained weights.
    Returns:
        A U-Net model using EfficientNetB4 as backbone.
    """
    # Input
    inputs = layers.Input(input_shape)

    # Loading pre trained model
    ResNet50 = ResNet50V2(include_top=False, weights=weight, input_tensor=inputs)

    # Encoder
    s1 = ResNet50.get_layer('input_1').output  # 512 x 512
    s2 = ResNet50.get_layer('conv1_conv').output  # 256 x 256
    s3 = ResNet50.get_layer('conv2_block3_1_relu').output  # 128 x 128
    s4 = ResNet50.get_layer('conv3_block4_1_relu').output  # 64 x 64

    # Bottleneck
    b1 = ResNet50.get_layer('conv4_block6_1_relu').output  # 32 x 32

    # Decoder
    d1 = decoder_block(b1, s4, 512)  # 64 x 64
    d2 = decoder_block(d1, s3, 256)    # 128 x 128
    d3 = decoder_block(d2, s2, 128)   # 256 x 256
    d4 = decoder_block(d3, s1, 64)   # 512 x 512

    # Output
    outputs = layers.Conv2D(1, 1, padding='same', activation='sigmoid')(d4)

    model = Model(inputs, outputs, name='ResNet50V2_U-Net')
    return model

# %%
model = ResNet50V2_unet()

# %%
model.summary()
# Out:
# Model: "ResNet50V2_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 518, 518, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 256, 256, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 258, 258, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 128, 128, 64  0           ['pool1_pad[0][0]']
#                                 )
#
#  conv2_block1_preact_bn (BatchN  (None, 128, 128, 64  256        ['pool1_pool[0][0]']
#  ormalization)                  )
#
#  conv2_block1_preact_relu (Acti  (None, 128, 128, 64  0          ['conv2_block1_preact_bn[0][0]']
#  vation)                        )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 64  4096        ['conv2_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 130, 130, 64  0          ['conv2_block1_1_relu[0][0]']
#  g2D)                           )
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 64  36864       ['conv2_block1_2_pad[0][0]']
#                                 )
#
#  conv2_block1_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block1_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_2_bn[0][0]']
#  n)                             )
#
#  conv2_block1_0_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block1_preact_relu[0][0]'
#                                 6)                               ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block1_2_relu[0][0]']
#                                 6)
#
#  conv2_block1_out (Add)         (None, 128, 128, 25  0           ['conv2_block1_0_conv[0][0]',
#                                 6)                                'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 128, 128, 25  1024       ['conv2_block1_out[0][0]']
#  ormalization)                  6)
#
#  conv2_block2_preact_relu (Acti  (None, 128, 128, 25  0          ['conv2_block2_preact_bn[0][0]']
#  vation)                        6)
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 64  16384       ['conv2_block2_preact_relu[0][0]'
#                                 )                                ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 130, 130, 64  0          ['conv2_block2_1_relu[0][0]']
#  g2D)                           )
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 64  36864       ['conv2_block2_2_pad[0][0]']
#                                 )
#
#  conv2_block2_2_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block2_2_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_2_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block2_2_bn[0][0]']
#  n)                             )
#
#  conv2_block2_3_conv (Conv2D)   (None, 128, 128, 25  16640       ['conv2_block2_2_relu[0][0]']
#                                 6)
#  conv2_block2_out (Add)         (None, 128, 128, 25  0           ['conv2_block1_out[0][0]',
#                                 6)                                'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 128, 128, 25  1024       ['conv2_block2_out[0][0]']
#  ormalization)                  6)
#
#  conv2_block3_preact_relu (Acti  (None, 128, 128, 25  0          ['conv2_block3_preact_bn[0][0]']
#  vation)                        6)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 64  16384       ['conv2_block3_preact_relu[0][0]'
#                                 )                                ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 64  256        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 130, 130, 64  0          ['conv2_block3_1_relu[0][0]']
#  g2D)                           )
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 64, 64, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 64, 64, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 64, 64, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 66, 66, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 64, 64, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 64, 64, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 64, 64, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 64, 64, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 66, 66, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 64, 64, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 64, 64, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 64, 64, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 66, 66, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 64, 64, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 64, 64, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 64, 64, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 64, 64, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 66, 66, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 32, 32, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 34, 34, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 32, 32, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 32, 32, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 32, 32, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 32, 32, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 34, 34, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 32, 32, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 32, 32, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 32, 32, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 34, 34, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 32, 32, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 32, 32, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 32, 32, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 34, 34, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 32, 32, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 32, 32, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 32, 32, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 34, 34, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 32, 32, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 32, 32, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 32, 32, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 32, 32, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 32, 32, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 32, 32, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  1180160    ['conv4_block6_1_relu[0][0]']
#  ose)
#
#  batch_normalization (BatchNorm  (None, 64, 64, 512)  2048       ['conv2d_transpose[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 64, 64, 640)  0           ['batch_normalization[0][0]',
#                                                                   'conv3_block4_1_relu[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 512)  2949632     ['concatenate[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d[0][0]']
#  rmalization)
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 512)  2359808     ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  1179904    ['batch_normalization_2[0][0]']
#  spose)                         6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)                   6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 32  0           ['batch_normalization_3[0][0]',
#                                 0)                                'conv2_block3_1_relu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 25  737536      ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_2[0][0]']
#  rmalization)                   6)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 25  590080      ['batch_normalization_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  295040     ['batch_normalization_5[0][0]']
#  spose)                         8)
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 12  512        ['conv2d_transpose_2[0][0]']
#  rmalization)                   8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 19  0           ['batch_normalization_6[0][0]',
#                                 2)                                'conv1_conv[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  221312      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  147584      ['batch_normalization_7[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  73792      ['batch_normalization_8[0][0]']
#  spose)                         )
#
#  batch_normalization_9 (BatchNo  (None, 512, 512, 64  256        ['conv2d_transpose_3[0][0]']
#  rmalization)                   )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 67  0           ['batch_normalization_9[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 512, 512, 64  256        ['conv2d_6[0][0]']
#  ormalization)                  )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 64  36928       ['batch_normalization_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 512, 512, 64  256        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 1)  65          ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 17,541,441
# Trainable params: 17,511,233
# Non-trainable params: 30,208
# __________________________________________________________________________________________________

# %% [markdown]
# ## DenseNet201

# %%
def DenseNet201_unet(input_shape=(512, 512, 3), weight='imagenet'):
    """
    Creates a neural network using the U-Net architecture and DenseNet201 as backbone.
    Args:
        input_shape: The size of the input image.
        weight: Pre-trained weights.
    Returns:
        A U-Net model using EfficientNetB4 as backbone.
    """
    # Input
    inputs = layers.Input(input_shape)

    # Loading pre trained model
    DenseNet = DenseNet201(include_top=False, weights=weight, input_tensor=inputs)

    # Encoder
    s1 = DenseNet.get_layer('input_1').output  # 512 x 512
    s2 = DenseNet.get_layer('conv1/relu').output  # 256 x 256
    s3 = DenseNet.get_layer('pool2_conv').output  # 128 x 128
    s4 = DenseNet.get_layer('pool3_conv').output  # 64 x 64

    # Bottleneck
    b1 = DenseNet.get_layer('pool4_conv').output  # 32 x 32

    # Decoder
    d1 = decoder_block(b1, s4, 512)  # 64 x 64
    d2 = decoder_block(d1, s3, 256)    # 128 x 128
    d3 = decoder_block(d2, s2, 128)   # 256 x 256
    d4 = decoder_block(d3, s1, 64)   # 512 x 512

    # Output
    outputs = layers.Conv2D(1, 1, padding='same', activation='sigmoid')(d4)

    model = Model(inputs, outputs, name='DenseNet201_U-Net')
    return model

# %%
model = DenseNet201_unet()

# %%
model.summary()
# Out:
# Model: "DenseNet201_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 518, 518, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 256, 256, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 256, 256, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 258, 258, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 128, 128, 64  0           ['zero_padding2d_1[0][0]']
#                                 )
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 128, 64  256        ['pool1[0][0]']
#  ization)                       )
#
#  conv2_block1_0_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_0_bn[0][0]']
#  n)                             )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 12  8192        ['conv2_block1_0_relu[0][0]']
#                                 8)
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block1_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block1_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_concat (Concatena  (None, 128, 128, 96  0          ['pool1[0][0]',
#  te)                            )                                 'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 128, 128, 96  384        ['conv2_block1_concat[0][0]']
#  ization)                       )
#
#  conv2_block2_0_relu (Activatio  (None, 128, 128, 96  0          ['conv2_block2_0_bn[0][0]']
#  n)                             )
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 12  12288       ['conv2_block2_0_relu[0][0]']
#                                 8)
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block2_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_concat (Concatena  (None, 128, 128, 12  0          ['conv2_block1_concat[0][0]',
#  te)                            8)                                'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_concat[0][0]']
#  ization)                       8)
#
#  conv2_block3_0_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_0_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 12  16384       ['conv2_block3_0_relu[0][0]']
#                                 8)
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block3_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block3_1_relu[0][0]']
#                                 )
#  conv2_block3_concat (Concatena  (None, 128, 128, 16  0          ['conv2_block2_concat[0][0]',
#  te)                            0)                                'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 128, 128, 16  640        ['conv2_block3_concat[0][0]']
#  ization)                       0)
#
#  conv2_block4_0_relu (Activatio  (None, 128, 128, 16  0          ['conv2_block4_0_bn[0][0]']
#  n)                             0)
#
#  conv2_block4_1_conv (Conv2D)   (None, 128, 128, 12  20480       ['conv2_block4_0_relu[0][0]']
#                                 8)
#
#  conv2_block4_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block4_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block4_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block4_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block4_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block4_1_relu[0][0]']
#                                 )
#
#  conv2_block4_concat (Concatena  (None, 128, 128, 19  0          ['conv2_block3_concat[0][0]',
#  te)                            2)                                'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 128, 128, 19  768        ['conv2_block4_concat[0][0]']
#  ization)                       2)
#
#  conv2_block5_0_relu (Activatio  (None, 128, 128, 19  0          ['conv2_block5_0_bn[0][0]']
#  n)                             2)
#
#  conv2_block5_1_conv (Conv2D)   (None, 128, 128, 12  24576       ['conv2_block5_0_relu[0][0]']
#                                 8)
#
#  conv2_block5_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block5_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block5_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block5_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block5_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block5_1_relu[0][0]']
#                                 )
#
#  conv2_block5_concat (Concatena  (None, 128, 128, 22  0          ['conv2_block4_concat[0][0]',
#  te)                            4)                                'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 128, 128, 22  896        ['conv2_block5_concat[0][0]']
#  ization)                       4)
#
#  conv2_block6_0_relu (Activatio  (None, 128, 128, 22  0          ['conv2_block6_0_bn[0][0]']
#  n)                             4)
#
#  conv2_block6_1_conv (Conv2D)   (None, 128, 128, 12  28672       ['conv2_block6_0_relu[0][0]']
#                                 8)
#
#  conv2_block6_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block6_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block6_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block6_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block6_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block6_1_relu[0][0]']
#                                 )
#
#  conv2_block6_concat (Concatena  (None, 128, 128, 25  0          ['conv2_block5_concat[0][0]',
#  te)                            6)                                'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 128, 128, 25  1024        ['conv2_block6_concat[0][0]']
#                                 6)
#
#  pool2_relu (Activation)        (None, 128, 128, 25  0           ['pool2_bn[0][0]']
#                                 6)
#
#  pool2_conv (Conv2D)            (None, 128, 128, 12  32768       ['pool2_relu[0][0]']
#                                 8)
#
#  pool2_pool (AveragePooling2D)  (None, 64, 64, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 64, 64, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 64, 64, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 64, 64, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 64, 64, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 64, 64, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 64, 64, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 64, 64, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 64, 64, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 64, 64, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 64, 64, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 64, 64, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 64, 64, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 64, 64, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 64, 64, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 64, 64, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 64, 64, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 64, 64, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 64, 64, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 64, 64, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 64, 64, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 64, 64, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 64, 64, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 64, 64, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 64, 64, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 64, 64, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 64, 64, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 64, 64, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 64, 64, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 64, 64, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 64, 64, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 64, 64, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 64, 64, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 64, 64, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 64, 64, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 64, 64, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 64, 64, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 64, 64, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 64, 64, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 32, 32, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 32, 32, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#  conv4_block2_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 32, 32, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 32, 32, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 32, 32, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 32, 32, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
# ...
#  lization)
#
#  conv4_block45_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block45_1_bn[0][0]']
#  on)
#
#  conv4_block45_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block45_1_relu[0][0]']
#
#  conv4_block45_concat (Concaten  (None, 32, 32, 1696  0          ['conv4_block44_concat[0][0]',
#  ate)                           )                                 'conv4_block45_2_conv[0][0]']
#
#  conv4_block46_0_bn (BatchNorma  (None, 32, 32, 1696  6784       ['conv4_block45_concat[0][0]']
#  lization)                      )
#
#  conv4_block46_0_relu (Activati  (None, 32, 32, 1696  0          ['conv4_block46_0_bn[0][0]']
#  on)                            )
#
#  conv4_block46_1_conv (Conv2D)  (None, 32, 32, 128)  217088      ['conv4_block46_0_relu[0][0]']
#
#  conv4_block46_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block46_1_conv[0][0]']
#  lization)
#
#  conv4_block46_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block46_1_bn[0][0]']
#  on)
#
#  conv4_block46_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block46_1_relu[0][0]']
#
#  conv4_block46_concat (Concaten  (None, 32, 32, 1728  0          ['conv4_block45_concat[0][0]',
#  ate)                           )                                 'conv4_block46_2_conv[0][0]']
#
#  conv4_block47_0_bn (BatchNorma  (None, 32, 32, 1728  6912       ['conv4_block46_concat[0][0]']
#  lization)                      )
#
#  conv4_block47_0_relu (Activati  (None, 32, 32, 1728  0          ['conv4_block47_0_bn[0][0]']
#  on)                            )
#
#  conv4_block47_1_conv (Conv2D)  (None, 32, 32, 128)  221184      ['conv4_block47_0_relu[0][0]']
#
#  conv4_block47_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block47_1_conv[0][0]']
#  lization)
#
#  conv4_block47_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block47_1_bn[0][0]']
#  on)
#
#  conv4_block47_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block47_1_relu[0][0]']
#
#  conv4_block47_concat (Concaten  (None, 32, 32, 1760  0          ['conv4_block46_concat[0][0]',
#  ate)                           )                                 'conv4_block47_2_conv[0][0]']
#
#  conv4_block48_0_bn (BatchNorma  (None, 32, 32, 1760  7040       ['conv4_block47_concat[0][0]']
#  lization)                      )
#
#  conv4_block48_0_relu (Activati  (None, 32, 32, 1760  0          ['conv4_block48_0_bn[0][0]']
#  on)                            )
#
#  conv4_block48_1_conv (Conv2D)  (None, 32, 32, 128)  225280      ['conv4_block48_0_relu[0][0]']
#
#  conv4_block48_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block48_1_conv[0][0]']
#  lization)
#
#  conv4_block48_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block48_1_bn[0][0]']
#  on)
#
#  conv4_block48_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block48_1_relu[0][0]']
#
#  conv4_block48_concat (Concaten  (None, 32, 32, 1792  0          ['conv4_block47_concat[0][0]',
#  ate)                           )                                 'conv4_block48_2_conv[0][0]']
#
#  pool4_bn (BatchNormalization)  (None, 32, 32, 1792  7168        ['conv4_block48_concat[0][0]']
#                                 )
#
#  pool4_relu (Activation)        (None, 32, 32, 1792  0           ['pool4_bn[0][0]']
#                                 )
#
#  pool4_conv (Conv2D)            (None, 32, 32, 896)  1605632     ['pool4_relu[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  4129280    ['pool4_conv[0][0]']
#  ose)
#
#  batch_normalization (BatchNorm  (None, 64, 64, 512)  2048       ['conv2d_transpose[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 64, 64, 768)  0           ['batch_normalization[0][0]',
#                                                                   'pool3_conv[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 512)  3539456     ['concatenate[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d[0][0]']
#  rmalization)
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 512)  2359808     ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  1179904    ['batch_normalization_2[0][0]']
#  spose)                         6)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)                   6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 38  0           ['batch_normalization_3[0][0]',
#                                 4)                                'pool2_conv[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 25  884992      ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_2[0][0]']
#  rmalization)                   6)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 25  590080      ['batch_normalization_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_3[0][0]']
#  rmalization)                   6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  295040     ['batch_normalization_5[0][0]']
#  spose)                         8)
#
#  batch_normalization_6 (BatchNo  (None, 256, 256, 12  512        ['conv2d_transpose_2[0][0]']
#  rmalization)                   8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 19  0           ['batch_normalization_6[0][0]',
#                                 2)                                'conv1/relu[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 12  221312      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 12  512        ['conv2d_4[0][0]']
#  rmalization)                   8)
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 12  147584      ['batch_normalization_7[0][0]']
#                                 8)
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  73792      ['batch_normalization_8[0][0]']
#  spose)                         )
#
#  batch_normalization_9 (BatchNo  (None, 512, 512, 64  256        ['conv2d_transpose_3[0][0]']
#  rmalization)                   )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 67  0           ['batch_normalization_9[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 64  38656       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 512, 512, 64  256        ['conv2d_6[0][0]']
#  ormalization)                  )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 64  36928       ['batch_normalization_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 512, 512, 64  256        ['conv2d_7[0][0]']
#  ormalization)                  )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 1)  65          ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 24,746,881
# Trainable params: 24,613,185
# Non-trainable params: 133,696
# __________________________________________________________________________________________________
